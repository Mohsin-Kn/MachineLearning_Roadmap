# %%
#import library
import pandas as pd

# %%
df =pd.read_csv("CreditCard.csv") #using credit card dataset

# %%
df
# Out:
#      card  reports       age  income     share  expenditure owner selfemp  \
# 0     yes        0  37.66667  4.5200  0.033270   124.983300   yes      no
# 1     yes        0  33.25000  2.4200  0.005217     9.854167    no      no
# 2     yes        0  33.66667  4.5000  0.004156    15.000000   yes      no
# 3     yes        0  30.50000  2.5400  0.065214   137.869200    no      no
# 4     yes        0  32.16667  9.7867  0.067051   546.503300   yes      no
# ...   ...      ...       ...     ...       ...          ...   ...     ...
# 1314  yes        0  33.58333  4.5660  0.002146     7.333333   yes      no
# 1315   no        5  23.91667  3.1920  0.000376     0.000000    no      no
# 1316  yes        0  40.58333  4.6000  0.026513   101.298300   yes      no
# 1317  yes        0  32.83333  3.7000  0.008999    26.996670    no     yes
# 1318  yes        0  48.25000  3.7000  0.111619   344.157500   yes      no
#
#       dependents  months  majorcards  active
# ...

# %%
df.describe()
# Out:
#            reports          age       income        share  expenditure  \
# count  1319.000000  1319.000000  1319.000000  1319.000000  1319.000000
# mean      0.456406    33.213103     3.365376     0.068732   185.057071
# std       1.345267    10.142783     1.693902     0.094656   272.218917
# min       0.000000     0.166667     0.210000     0.000109     0.000000
# 25%       0.000000    25.416670     2.243750     0.002316     4.583333
# 50%       0.000000    31.250000     2.900000     0.038827   101.298300
# 75%       0.000000    39.416670     4.000000     0.093617   249.035800
# max      14.000000    83.500000    13.500000     0.906320  3099.505000
#
#         dependents       months   majorcards       active
# count  1319.000000  1319.000000  1319.000000  1319.000000
# mean      0.993935    55.267627     0.817286     6.996967
# std       1.247745    66.271746     0.386579     6.305812
# min       0.000000     0.000000     0.000000     0.000000
# ...

# %%
df.isna().sum()
# Out:
# card           0
# reports        0
# age            0
# income         0
# share          0
# expenditure    0
# owner          0
# selfemp        0
# dependents     0
# months         0
# majorcards     0
# active         0
# dtype: int64

# %%
df.active.unique()
# Out:
# array([12, 13,  5,  7,  1,  3,  6, 18, 20,  0, 22,  8, 10,  2, 17, 19, 15,
#        16, 14,  4, 11,  9, 29, 27, 26, 21, 23, 46, 25, 31, 28, 24, 33, 32,
#        44])

# %%
import seaborn as sns

# %%
sns.boxplot(data=df["expenditure"])
# Out:
# <Axes: ylabel='expenditure'>

# %%
data =pd.get_dummies(data=df,drop_first=True)

# %%
data.card_yes.unique()
# Out:
# array([ True, False])

# %%
data
# Out:
#       reports       age  income     share  expenditure  dependents  months  \
# 0           0  37.66667  4.5200  0.033270   124.983300           3      54
# 1           0  33.25000  2.4200  0.005217     9.854167           3      34
# 2           0  33.66667  4.5000  0.004156    15.000000           4      58
# 3           0  30.50000  2.5400  0.065214   137.869200           0      25
# 4           0  32.16667  9.7867  0.067051   546.503300           2      64
# ...       ...       ...     ...       ...          ...         ...     ...
# 1314        0  33.58333  4.5660  0.002146     7.333333           0      94
# 1315        5  23.91667  3.1920  0.000376     0.000000           3      12
# 1316        0  40.58333  4.6000  0.026513   101.298300           2       1
# 1317        0  32.83333  3.7000  0.008999    26.996670           0      60
# 1318        0  48.25000  3.7000  0.111619   344.157500           2       2
#
#       majorcards  active  card_yes  owner_yes  selfemp_yes
# ...

# %%
X=data.drop(['card_yes'],axis=1)
y=data["card_yes"]

# %%
X.shape
# Out:
# (1319, 11)

# %%
y.shape
# Out:
# (1319,)

# %%
from sklearn.model_selection import train_test_split
X_test,X_Train,y_test,y_train=train_test_split(X,y,random_state=42,test_size=.3)

# %%
X_test
# Out:
#       reports       age  income     share  expenditure  dependents  months  \
# 1156        0  25.91667   3.000  0.061896    154.74000           0      40
# 1023        0  22.25000   2.800  0.253299    590.94840           1       6
# 224         2  35.16667   3.840  0.000313      0.00000           0      38
# 590         0  27.00000   2.675  0.034820     77.28667           0     135
# 274         1  34.83333   3.200  0.065676    175.13670           2      25
# ...       ...       ...     ...       ...          ...         ...     ...
# 1095        0  33.25000   3.700  0.000324      0.00000           2      72
# 1130        0  39.08333   5.100  0.049524    210.22830           3      60
# 1294        0  31.58333   2.550  0.142905    303.67420           1      60
# 860         0  27.16667   2.200  0.007310     12.65083           0      60
# 1126        0  28.16667   1.548  0.000775      0.00000           3       5
#
#       majorcards  active  owner_yes  selfemp_yes
# ...

# %%
X_Train
# Out:
#       reports       age  income     share  expenditure  dependents  months  \
# 677         0  32.58333  1.8142  0.054141     81.43500           0       9
# 1046        0  23.91667  2.0000  0.100191    166.90170           0       9
# 610         0  36.75000  3.0000  0.032497     80.82584           3     134
# 49          0  27.75000  7.0000  0.110585    644.82830           0       0
# 1284        0  49.16667  3.1144  0.008495     21.46500           1     154
# ...       ...       ...     ...       ...          ...         ...     ...
# 141         0  41.50000  3.8000  0.083156    263.32750           0      67
# 1169        0  60.25000  2.8000  0.043723    101.85420           3     232
# 613         0  21.25000  1.9900  0.034963     57.98083           2       8
# 543         0  28.16667  2.0000  0.060250    100.41670           1      38
# 139         0  42.00000  3.6000  0.017851     53.30167           0      41
#
#       majorcards  active  owner_yes  selfemp_yes
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf =RandomForestClassifier(n_estimators=100,max_features='sqrt',n_jobs=-1)

# %%
rf.fit(X_Train,y_train)
# Out:
# RandomForestClassifier(n_jobs=-1)

# %%
pred=rf.predict(X_test)

# %%
from sklearn.metrics import classification_report, f1_score,accuracy_score

# %%
print(classification_report(pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#        False       1.00      0.94      0.97       220
#         True       0.98      1.00      0.99       703
#
#     accuracy                           0.98       923
#    macro avg       0.99      0.97      0.98       923
# weighted avg       0.99      0.98      0.98       923

# %%
print(accuracy_score(pred,y_test)) #checking accuracy
# Out:
# 0.9848320693391116

# %%
print(f1_score(pred,y_test))
# Out:
# 0.9901408450704225

# %%
X
# Out:
#       reports       age  income     share  expenditure  dependents  months  \
# 0           0  37.66667  4.5200  0.033270   124.983300           3      54
# 1           0  33.25000  2.4200  0.005217     9.854167           3      34
# 2           0  33.66667  4.5000  0.004156    15.000000           4      58
# 3           0  30.50000  2.5400  0.065214   137.869200           0      25
# 4           0  32.16667  9.7867  0.067051   546.503300           2      64
# ...       ...       ...     ...       ...          ...         ...     ...
# 1314        0  33.58333  4.5660  0.002146     7.333333           0      94
# 1315        5  23.91667  3.1920  0.000376     0.000000           3      12
# 1316        0  40.58333  4.6000  0.026513   101.298300           2       1
# 1317        0  32.83333  3.7000  0.008999    26.996670           0      60
# 1318        0  48.25000  3.7000  0.111619   344.157500           2       2
#
#       majorcards  active  owner_yes  selfemp_yes
# ...

# %% [markdown]
# ## Hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'n_estimators': [50, 100, 200],       # Number of trees in the forest
    'max_depth': [10, 20, None],          # Maximum depth of the tree
    'min_samples_split': [2, 5, 10],      # Minimum number of samples required to split a node
    'min_samples_leaf': [1, 2, 4],        # Minimum number of samples required at each leaf node
    'max_features': ['sqrt', 'log2'],     # Number of features to consider at each split
}

grid=GridSearchCV(estimator=rf,param_grid=param_grid,cv=5,verbose=2,n_jobs=-1)

# %%
grid.fit(X_Train, y_train)
# Out:
# Fitting 5 folds for each of 162 candidates, totalling 810 fits
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.3s
# ...

# %%
print(grid.best_estimator_)
# Out:
# RandomForestClassifier(max_depth=10, n_estimators=50, n_jobs=-1)

# %%
print(grid.best_params_)
# Out:
# {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}

# %%
print(grid.best_score_)
# Out:
# 0.9772784810126582

# %%
print(grid.best_index_)
# Out:
# 0

# %%
best_rf_model= grid.best_estimator_

# %%
prediction = best_rf_model.predict(X_test)

# %%
print(accuracy_score(prediction,y_test))
# Out:
# 0.9848320693391116
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.6s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.3s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.2s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.6s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.3s
# ...
