# %%
import pandas as pd
import xgboost as xgb
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import balanced_accuracy_score, roc_auc_score,make_scorer,confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

# %%
#import dataset (customer churn)

df = pd.read_excel("Data/Telco_customer_churn.xlsx")

# %%
df.head()
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender  ...        Contract  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male  ...  Month-to-month
# 1   34.059281, -118.30742  34.059281 -118.307420  Female  ...  Month-to-month
# 2  34.048013, -118.293953  34.048013 -118.293953  Female  ...  Month-to-month
# 3  34.062125, -118.315709  34.062125 -118.315709  Female  ...  Month-to-month
# 4  34.039224, -118.266293  34.039224 -118.266293    Male  ...  Month-to-month
#
# ...

# %%
#the last four features or variables contain exit interview and already exit so we dont use it for prediction
df.drop(["Churn Label","Churn Score","CLTV","Churn Reason"],axis=1,inplace=True)

# %%
df.head()
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender  ...  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male  ...
# 1   34.059281, -118.30742  34.059281 -118.307420  Female  ...
# 2  34.048013, -118.293953  34.048013 -118.293953  Female  ...
# 3  34.062125, -118.315709  34.062125 -118.315709  Female  ...
# 4  34.039224, -118.266293  34.039224 -118.266293    Male  ...
#
#   Device Protection Tech Support Streaming TV  Streaming Movies  \
# 0                No           No           No                No
# ...

# %%
#now check those columns which have single value so we dont use for prediciton
#following columns have single value so we will drop it 
print(df["Country"].unique())
print(df["Count"].unique())
print(df["State"].unique())
# Out:
# ['United States']
# [1]
# ['California']

# %%
#also we will drop CustomerID AND  Lat Long beacue we have separate columns for that 
df.drop(["CustomerID","Count","Lat Long","Country","State"],axis=1,inplace=True)

# %%
df.head()
# Out:
#           City  Zip Code   Latitude   Longitude  Gender Senior Citizen  \
# 0  Los Angeles     90003  33.964131 -118.272783    Male             No
# 1  Los Angeles     90005  34.059281 -118.307420  Female             No
# 2  Los Angeles     90006  34.048013 -118.293953  Female             No
# 3  Los Angeles     90010  34.062125 -118.315709  Female             No
# 4  Los Angeles     90015  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure Months Phone Service  ... Device Protection  \
# 0      No         No              2           Yes  ...                No
# 1      No        Yes              2           Yes  ...                No
# 2      No        Yes              8           Yes  ...               Yes
# 3     Yes        Yes             28           Yes  ...               Yes
# 4      No        Yes             49           Yes  ...               Yes
#
#   Tech Support Streaming TV Streaming Movies        Contract  \
# ...

# %%
df.replace(r"\s+","_",regex=True,inplace=True) #replace _ between city names

# %%
df
# Out:
#               City  Zip Code   Latitude   Longitude  Gender Senior Citizen  \
# 0      Los_Angeles     90003  33.964131 -118.272783    Male             No
# 1      Los_Angeles     90005  34.059281 -118.307420  Female             No
# 2      Los_Angeles     90006  34.048013 -118.293953  Female             No
# 3      Los_Angeles     90010  34.062125 -118.315709  Female             No
# 4      Los_Angeles     90015  34.039224 -118.266293    Male             No
# ...            ...       ...        ...         ...     ...            ...
# 7038       Landers     92285  34.341737 -116.539416  Female             No
# 7039      Adelanto     92301  34.667815 -117.536183    Male             No
# 7040         Amboy     92304  34.559882 -115.637164  Female             No
# 7041  Angelus_Oaks     92305  34.167800 -116.864330  Female             No
# 7042  Apple_Valley     92308  34.424926 -117.184503    Male             No
#
#      Partner Dependents  Tenure Months Phone Service  ...  \
# ...

# %%
df["City"].unique()
# Out:
# array(['Los_Angeles', 'Beverly_Hills', 'Huntington_Park', ..., 'Standish',
#        'Tulelake', 'Olympic_Valley'], dtype=object)

# %%
df.columns=df.columns.str.replace(" ","_") #remove white spaces from columns names

# %%
df.head()
# Out:
#           City  Zip_Code   Latitude   Longitude  Gender Senior_Citizen  \
# 0  Los_Angeles     90003  33.964131 -118.272783    Male             No
# 1  Los_Angeles     90005  34.059281 -118.307420  Female             No
# 2  Los_Angeles     90006  34.048013 -118.293953  Female             No
# 3  Los_Angeles     90010  34.062125 -118.315709  Female             No
# 4  Los_Angeles     90015  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure_Months Phone_Service  ... Device_Protection  \
# 0      No         No              2           Yes  ...                No
# 1      No        Yes              2           Yes  ...                No
# 2      No        Yes              8           Yes  ...               Yes
# 3     Yes        Yes             28           Yes  ...               Yes
# 4      No        Yes             49           Yes  ...               Yes
#
#   Tech_Support Streaming_TV Streaming_Movies        Contract  \
# ...

# %% [markdown]
# ### Remove missing values

# %%
df.dtypes
# Out:
# City                  object
# Zip_Code               int64
# Latitude             float64
# Longitude            float64
# Gender                object
# Senior_Citizen        object
# Partner               object
# Dependents            object
# Tenure_Months          int64
# Phone_Service         object
# Multiple_Lines        object
# Internet_Service      object
# Online_Security       object
# Online_Backup         object
# Device_Protection     object
# Tech_Support          object
# Streaming_TV          object
# Streaming_Movies      object
# Contract              object
# Paperless_Billing     object
# Payment_Method        object
# Monthly_Charges      float64
# Total_Charges         object
# Churn_Value            int64
# dtype: object

# %%
#so we saw that total-charges have numerica values but have object datatype , so we will change it to numeric
# df["Total_Charges"]=pd.to_numeric(df["Total_Charges"]) #before we didnot remove missing values this will give us error

# %%
len(df.loc[df["Total_Charges"] == "_"])
# Out:
# 0

# %%
#so we have 11 missing values now we will replace it with 0
df.loc[(df["Total_Charges"] == "_"),"Total_Charges"] = 0

# %%
df.loc[(df["Total_Charges"]=="_")]
# Out:
# Empty DataFrame
# Columns: [City, Zip_Code, Latitude, Longitude, Gender, Senior_Citizen, Partner, Dependents, Tenure_Months, Phone_Service, Multiple_Lines, Internet_Service, Online_Security, Online_Backup, Device_Protection, Tech_Support, Streaming_TV, Streaming_Movies, Contract, Paperless_Billing, Payment_Method, Monthly_Charges, Total_Charges, Churn_Value]
# Index: []
#
# [0 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['City', 'Zip_Code', 'Latitude', 'Longitude', 'Gender', 'Senior_Citizen',
#        'Partner', 'Dependents', 'Tenure_Months', 'Phone_Service',
#        'Multiple_Lines', 'Internet_Service', 'Online_Security',
#        'Online_Backup', 'Device_Protection', 'Tech_Support', 'Streaming_TV',
#        'Streaming_Movies', 'Contract', 'Paperless_Billing', 'Payment_Method',
#        'Monthly_Charges', 'Total_Charges', 'Churn_Value'],
#       dtype='object')

# %%
df.loc[(df["Total_Charges"]== 0)]
# Out:
#                 City  Zip_Code   Latitude   Longitude  Gender Senior_Citizen  \
# 2234  San_Bernardino     92408  34.084909 -117.258107  Female             No
# 2438    Independence     93526  36.869584 -118.189241    Male             No
# 2568       San_Mateo     94401  37.590421 -122.306467  Female             No
# 2667       Cupertino     95014  37.306612 -122.080621    Male             No
# 2856        Redcrest     95569  40.363446 -123.835041  Female             No
# 4331     Los_Angeles     90029  34.089953 -118.294824    Male             No
# 4687        Sun_City     92585  33.739412 -117.173334    Male             No
# 5104      Ben_Lomond     95005  37.078873 -122.090386  Female             No
# 5719        La_Verne     91750  34.144703 -117.770299    Male             No
# 6772            Bell     90201  33.970343 -118.171368  Female             No
# 6840      Wilmington     90744  33.782068 -118.262263    Male             No
#
# ...

# %%
df.isna().sum()
# Out:
# City                 0
# Zip_Code             0
# Latitude             0
# Longitude            0
# Gender               0
# Senior_Citizen       0
# Partner              0
# Dependents           0
# Tenure_Months        0
# Phone_Service        0
# Multiple_Lines       0
# Internet_Service     0
# Online_Security      0
# Online_Backup        0
# Device_Protection    0
# Tech_Support         0
# Streaming_TV         0
# Streaming_Movies     0
# Contract             0
# Paperless_Billing    0
# Payment_Method       0
# Monthly_Charges      0
# Total_Charges        0
# Churn_Value          0
# dtype: int64

# %%
#now that we remove missing values in tota charges so will change it into numeric
df["Total_Charges"]=pd.to_numeric(df["Total_Charges"])

# %%
df.dtypes
# Out:
# City                  object
# Zip_Code               int64
# Latitude             float64
# Longitude            float64
# Gender                object
# Senior_Citizen        object
# Partner               object
# Dependents            object
# Tenure_Months          int64
# Phone_Service         object
# Multiple_Lines        object
# Internet_Service      object
# Online_Security       object
# Online_Backup         object
# Device_Protection     object
# Tech_Support          object
# Streaming_TV          object
# Streaming_Movies      object
# Contract              object
# Paperless_Billing     object
# Payment_Method        object
# Monthly_Charges      float64
# Total_Charges        float64
# Churn_Value            int64
# dtype: object

# %% [markdown]
# ### now split the Data
#     . so in dataset we will predict churn value

# %%
X = df.drop("Churn_Value",axis=1).copy()
y=df["Churn_Value"].copy()

# %%
X.head()
# Out:
#           City  Zip_Code   Latitude   Longitude  Gender Senior_Citizen  \
# 0  Los_Angeles     90003  33.964131 -118.272783    Male             No
# 1  Los_Angeles     90005  34.059281 -118.307420  Female             No
# 2  Los_Angeles     90006  34.048013 -118.293953  Female             No
# 3  Los_Angeles     90010  34.062125 -118.315709  Female             No
# 4  Los_Angeles     90015  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure_Months Phone_Service  ... Online_Backup  \
# 0      No         No              2           Yes  ...           Yes
# 1      No        Yes              2           Yes  ...            No
# 2      No        Yes              8           Yes  ...            No
# 3     Yes        Yes             28           Yes  ...            No
# 4      No        Yes             49           Yes  ...           Yes
#
#   Device_Protection Tech_Support Streaming_TV Streaming_Movies  \
# ...

# %%
#now convert caterogical data into numerical using onehot encoding
import pandas as pd

# Categorical columns list
categorical_columns = [
    'City', 'Gender', 'Senior_Citizen', 'Partner', 'Dependents', 'Phone_Service',
    'Multiple_Lines', 'Internet_Service', 'Online_Security', 'Online_Backup',
    'Device_Protection', 'Tech_Support', 'Streaming_TV', 'Streaming_Movies',
    'Contract', 'Paperless_Billing', 'Payment_Method'
]

# Assuming df is your DataFrame
X_encoded= pd.get_dummies(X, columns=categorical_columns,dtype=int)
X_encoded
# Out:
#       Zip_Code   Latitude   Longitude  Tenure_Months  Monthly_Charges  \
# 0        90003  33.964131 -118.272783              2            53.85
# 1        90005  34.059281 -118.307420              2            70.70
# 2        90006  34.048013 -118.293953              8            99.65
# 3        90010  34.062125 -118.315709             28           104.80
# 4        90015  34.039224 -118.266293             49           103.70
# ...        ...        ...         ...            ...              ...
# 7038     92285  34.341737 -116.539416             72            21.15
# 7039     92301  34.667815 -117.536183             24            84.80
# 7040     92304  34.559882 -115.637164             72           103.20
# 7041     92305  34.167800 -116.864330             11            29.60
# 7042     92308  34.424926 -117.184503             66           105.65
#
#       Total_Charges  City_Acampo  City_Acton  City_Adelanto  City_Adin  ...  \
# ...

# %%
y.unique()
# Out:
# array([1, 0])

# %% [markdown]
# ### How xgboost handle missing data

# %% [markdown]
# <embed src="30_Days_ML/Day-13-Xgboost/missing_values_handling.pdf"/>

# %%
from IPython.display import IFrame

# Assuming the PDF is in the same directory as the notebook
IFrame('missing_values_handling.pdf', width=700, height=500)
# Out:
#         <iframe
#             width="700"
#             height="500"
#             src="missing_values_handling.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
sum(y)/len(y)
#now we have data imbalance 27% for class 1 which aleady left company
# Out:
# 0.2653698707936959

# %%
y.value_counts()
# Out:
# Churn_Value
# 0    5174
# 1    1869
# Name: count, dtype: int64

# %%
#we use stratify so that class have same proportion in test and train split
X_train,X_test,y_train,y_test=train_test_split(X_encoded,y,random_state=42,stratify=y)

# %%
sum(y_train)/len(y_train)
# Out:
# 0.2654297614539947

# %%
sum(y_test)/len(y_test)
# Out:
# 0.26519023282226006

# %%
#now we prepare our model for preediciton

model = xgb.XGBClassifier(objective="binary:logistic",
                          early_stopping_rounds=20,
                          #at some point the prediction not improve so we use 10 more 
                          # trees if these trees didnot improve predicion then we stop it
                          missing=np.nan,seed=42,eval_metric="aucpr")

# %%
model.fit(X_train,y_train,
          eval_set=[(X_test, y_test)],  # Validation data
          verbose=True,
         )
# Out:
# [0]	validation_0-aucpr:0.64135
# [1]	validation_0-aucpr:0.65171
# [2]	validation_0-aucpr:0.65991
# [3]	validation_0-aucpr:0.65350
# [4]	validation_0-aucpr:0.65743
# [5]	validation_0-aucpr:0.65051
# [6]	validation_0-aucpr:0.65827
# [7]	validation_0-aucpr:0.65980
# [8]	validation_0-aucpr:0.65751
# [9]	validation_0-aucpr:0.65389
# [10]	validation_0-aucpr:0.65572
# [11]	validation_0-aucpr:0.65920
# [12]	validation_0-aucpr:0.66010
# [13]	validation_0-aucpr:0.65963
# [14]	validation_0-aucpr:0.65877
# [15]	validation_0-aucpr:0.65791
# [16]	validation_0-aucpr:0.65808
# [17]	validation_0-aucpr:0.65742
# [18]	validation_0-aucpr:0.65770
# [19]	validation_0-aucpr:0.65698
# [20]	validation_0-aucpr:0.65733
# [21]	validation_0-aucpr:0.65646
# [22]	validation_0-aucpr:0.65650
# [23]	validation_0-aucpr:0.65270
# [24]	validation_0-aucpr:0.65346
# [25]	validation_0-aucpr:0.65371
# [26]	validation_0-aucpr:0.65406
# [27]	validation_0-aucpr:0.65384
# [28]	validation_0-aucpr:0.65367
# ...

# %%
disp = ConfusionMatrixDisplay.from_estimator(
    model, 
    X_test, 
    y_test,
    values_format="d", 
    display_labels=["not leave", "leave"]
)
plt.savefig("pic.png")
plt.show()
# plt.savefig("pic.png")

# %% [markdown]
# ### We do fine tuning to tune parameters  using Gridsearch and CR

# %%
model = xgb.XGBClassifier(
    seed=42,
    objective="binary:logistic",
    gamma=0.25,
    learning_rate=0.1,
    max_depth=4,
    reg_lambda=10,
    scale_pos_weight=3,
    subsample=0.9,
    colsample_bytree=0.5,
    early_stopping_rounds=10,
    eval_metric="aucpr"

)

# %%
model.fit(
    X_train,
    y_train,
    verbose=True,
    eval_set=[(X_test, y_test)],  # Validation data
)
# Out:
# [0]	validation_0-aucpr:0.55601
# [1]	validation_0-aucpr:0.60406
# [2]	validation_0-aucpr:0.61022
# [3]	validation_0-aucpr:0.61566
# [4]	validation_0-aucpr:0.61795
# [5]	validation_0-aucpr:0.61924
# [6]	validation_0-aucpr:0.62509
# [7]	validation_0-aucpr:0.63152
# [8]	validation_0-aucpr:0.63518
# [9]	validation_0-aucpr:0.62990
# [10]	validation_0-aucpr:0.65172
# [11]	validation_0-aucpr:0.65250
# [12]	validation_0-aucpr:0.65199
# [13]	validation_0-aucpr:0.65431
# [14]	validation_0-aucpr:0.65026
# [15]	validation_0-aucpr:0.64472
# [16]	validation_0-aucpr:0.64660
# [17]	validation_0-aucpr:0.64634
# [18]	validation_0-aucpr:0.65688
# [19]	validation_0-aucpr:0.66143
# [20]	validation_0-aucpr:0.66410
# [21]	validation_0-aucpr:0.66354
# [22]	validation_0-aucpr:0.66360
# [23]	validation_0-aucpr:0.66598
# [24]	validation_0-aucpr:0.66702
# [25]	validation_0-aucpr:0.66536
# [26]	validation_0-aucpr:0.66599
# [27]	validation_0-aucpr:0.66745
# [28]	validation_0-aucpr:0.66682
# ...

# %%
disp = ConfusionMatrixDisplay.from_estimator(
    model, 
    X_test, 
    y_test,
    values_format="d", 
    display_labels=["not leave", "leave"]
)
plt.show()
